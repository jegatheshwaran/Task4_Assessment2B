# %% [markdown]
# <a href="https://colab.research.google.com/github/jegatheshwaran/Task4_Assessment2B/blob/main/Task4_Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data1 = pd.read_csv('/content/college_1.csv')
data1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
data1_test = pd.DataFrame(data1)

# %%
data1_test
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
data2 = pd.read_csv('/content/college_2.csv')
data2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
merge_data = pd.concat([data1,data2])
merge_data.reset_index(inplace=True)
merge_data
# Out:
#      index           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        0      A.Dharani    82.0   20.0              24500           24500
# 1        1    V.JEEVITHA     82.0   20.0              21740           21740
# 2        2    HEMAVATHI.R   100.0  100.0              19680           19680
# 3        3    Mugunthan S   100.0   47.0              10610           10610
# 4        4    Sathammai.S   100.0    8.0               8980            8980
# ..     ...            ...     ...    ...                ...             ...
# 114     30  praveen raj j    24.0    0.0               2380            2380
# 115     31     AMARNATH D    -1.0   12.0               1890            1890
# 116     32           bala    32.0    0.0               1720            1720
# 117     33           XY Z    -1.0   -1.0                  0               0
# 118     34      Hariharan    -1.0   -1.0                  0               0
#
# ...

# %%
merge_data.to_csv('merge_data.csv')

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
exceeded_expectations = merge_data[(merge_data['CodeKata Score'] >15000)]
exceeded_expectations
# Out:
#     index           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       0      A.Dharani    82.0   20.0              24500           24500
# 1       1    V.JEEVITHA     82.0   20.0              21740           21740
# 2       2    HEMAVATHI.R   100.0  100.0              19680           19680
# 84      0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %%
exceeded_expectations = merge_data.loc[(merge_data['CodeKata Score'] > 15000)]
exceeded_expectations
# Out:
#     index           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       0      A.Dharani    82.0   20.0              24500           24500
# 1       1    V.JEEVITHA     82.0   20.0              21740           21740
# 2       2    HEMAVATHI.R   100.0  100.0              19680           19680
# 84      0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %%
exceeded_expectations.to_csv('exceeded_expectations.csv')

# %%
Reached_expectations = merge_data.loc[merge_data['CodeKata Score'] < 15000]
Reached_expectations
# Out:
#      index                  Name  python  mysql  Previous Geekions  \
# 3        3           Mugunthan S   100.0   47.0              10610
# 4        4           Sathammai.S   100.0    8.0               8980
# 5        5          NIVEESHWAR S   100.0    0.0               8200
# 6        6         KALAIARASAN K    85.0   47.0               7750
# 7        7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020
# ..     ...                   ...     ...    ...                ...
# 114     30         praveen raj j    24.0    0.0               2380
# 115     31            AMARNATH D    -1.0   12.0               1890
# 116     32                  bala    32.0    0.0               1720
# 117     33                  XY Z    -1.0   -1.0                  0
# 118     34             Hariharan    -1.0   -1.0                  0
#
#      CodeKata Score                                 Department  Rising  \
# 3             10610           Computer Science and Engineering       0
# ...

# %%
Reached_expectations.to_csv('Reached_expectations.csv')

# %%
Needs_Improvement = merge_data.loc[merge_data['CodeKata Score'] < 10000]
Needs_Improvement
# Out:
#      index                  Name  python  mysql  Previous Geekions  \
# 4        4           Sathammai.S   100.0    8.0               8980
# 5        5          NIVEESHWAR S   100.0    0.0               8200
# 6        6         KALAIARASAN K    85.0   47.0               7750
# 7        7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020
# 8        8            J.SUGANTHI    27.0   50.0               5860
# ..     ...                   ...     ...    ...                ...
# 114     30         praveen raj j    24.0    0.0               2380
# 115     31            AMARNATH D    -1.0   12.0               1890
# 116     32                  bala    32.0    0.0               1720
# 117     33                  XY Z    -1.0   -1.0                  0
# 118     34             Hariharan    -1.0   -1.0                  0
#
#      CodeKata Score                                 Department  Rising  \
# 4              8980           Computer Science and Engineering       0
# ...

# %%
Needs_Improvement.to_csv('Needs_Improvement.csv')

# %%
Unsatisfactory = merge_data.loc[merge_data['CodeKata Score'] < 7000]
Unsatisfactory
# Out:
#      index             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        8       J.SUGANTHI    27.0  50.00               5860            5860
# 9        9     thamizhpaana    29.0   0.00               5500            5500
# 10      10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11      11     Ponniyamma.R   100.0  11.25               5380            5380
# 12      12        SABAPATHI   100.0   0.00               5280            5280
# ..     ...              ...     ...    ...                ...             ...
# 114     30    praveen raj j    24.0   0.00               2380            2380
# 115     31       AMARNATH D    -1.0  12.00               1890            1890
# 116     32             bala    32.0   0.00               1720            1720
# 117     33             XY Z    -1.0  -1.00                  0               0
# 118     34        Hariharan    -1.0  -1.00                  0               0
#
# ...

# %%
Unsatisfactory.to_csv('Unsatisfactory.csv')

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %% [markdown]
# ###### No of students participated

# %%
merge_data['Name'].count()
# Out:
# 119

# %%
merge_data.to_csv('merge_data.csv')

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
a = merge_data['python'].value_counts()[100]
a
# Out:
# 41

# %%
b = merge_data.shape[0]
b
# Out:
# 119

# %%
c = a/b
c
# Out:
# 0.3445378151260504

# %%
a = merge_data['mysql'].value_counts()[100]
b = merge_data.shape[0]
c = a/b
c
# Out:
# 0.11764705882352941

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_star = merge_data.sort_values(by=['CodeKata Score'],ascending=False)
rising_star.head(3)
# Out:
#    index         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      0    A.Dharani    82.0   20.0              24500           24500
# 1      1  V.JEEVITHA     82.0   20.0              21740           21740
# 2      2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
rising_star = merge_data.sort_values(by=['Previous Geekions'],ascending=False)
rising_star.head(3)
# Out:
#    index         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      0    A.Dharani    82.0   20.0              24500           24500
# 1      1  V.JEEVITHA     82.0   20.0              21740           21740
# 2      2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt

piechart = plt.pie(merge_data['CodeKata Score'], labels = merge_data['Department'])

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
topper = merge_data.groupby(['Department'])['CodeKata Score'].max()
topper
# Out:
# Department
# Computer Science and Engineering             24500
# Electronics and Communication Engineering    10040
# Electronics and Electrical Engineering       19400
# Name: CodeKata Score, dtype: int64

# %%
topper1=merge_data.groupby(['Department']).max()
topper1
# Out:
#                                            index            Name  python  \
# Department
# Computer Science and Engineering              76     vijayakumar   100.0
# Electronics and Communication Engineering     73       vignesh B   100.0
# Electronics and Electrical Engineering        83  yaser ahamed.A   100.0
#
#                                            mysql  Previous Geekions  \
# Department
# Computer Science and Engineering           100.0              24500
# Electronics and Communication Engineering  100.0              10040
# Electronics and Electrical Engineering     100.0              19400
#
#                                            CodeKata Score  Rising  python_en  \
# Department
# Computer Science and Engineering                    24500    2000       78.0
# Electronics and Communication Engineering           10040     560       72.0
# Electronics and Electrical Engineering              19400    3140      100.0
#
# ...

# %%
topper.plot.bar()
plt.show()
